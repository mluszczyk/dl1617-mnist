# %%
import json
with open("digits.json") as f:
    data = json.load(f)

# %%
data
# Out:
# {'digits': [[-0.06949058175086975,
#    0.0014333589933812618,
#    -0.0615539513528347,
#    0.15013958513736725,
#    0.133623868227005,
#    0.057631880044937134,
#    0.09545183926820755,
#    -0.09676730632781982,
#    0.0129801444709301,
#    0.07220123708248138,
#    -0.044313400983810425,
#    0.015823349356651306,
#    0.11011583358049393,
#    0.020161768421530724,
#    -0.11401814967393875,
#    -0.10092000663280487,
#    -0.06764813512563705,
#    0.009178363718092442,
#    -0.03634626790881157,
#    -0.07983722537755966,
#    -0.03054782934486866,
#    0.13550029695034027,
#    -0.09295213967561722,
#    -0.019236072897911072,
#    0.028552846983075142,
#    -0.041527681052684784,
#    -0.06065322458744049,
#    -0.11836586147546768,
#    0.0005882382392883301,
#    0.09108281135559082,
#    -0.04247026517987251,
#    0.051181890070438385,
#    0.030986445024609566,
#    -0.06808781623840332,
#    0.07423191517591476,
#    -0.08430212736129761,
# ...

# %%
# %matplotlib inline
import numpy
from matplotlib import pyplot

for num, matrix in enumerate(data['digits']):
    pyplot.figure()
    pyplot.imshow(numpy.asarray(matrix).reshape(28, 28), cmap='gray')
